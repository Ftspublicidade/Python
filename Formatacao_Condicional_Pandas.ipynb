# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", None)

# %%
df = pd.read_excel("planilha_vendas.xlsx")

# %%
df.head()
# Out:
#    Cidade ID       Data  Vendas  LojaID  Qtde
# 0       22.0 2014-01-02  127.92  1036.0     1
# 1       22.0 2014-01-02   30.97  1036.0     1
# 2       22.0 2014-01-02   39.29  1036.0     1
# 3       22.0 2014-01-02  158.66  1036.0     1
# 4       22.0 2014-01-02  242.31  1036.0     1

# %%
df["Cidade ID"] = df["Cidade ID"].astype("object")

# %%
df.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row0_col2 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row1_col2 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7646a5e2_9967_11ea_b3ae_f8da0c854c28row2_col2 {
#             background-color:  #fed9c9;
#             color:  #000000;
# ...

# %%
df.style.bar(subset=['Vendas', 'Qtde'], color='#d65f5f')
# Out:
# <style  type="text/css" >
#     #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.7%, transparent 51.7%);
#         }    #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row0_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.6%, transparent 11.6%);
#         }    #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.0%, transparent 15.0%);
#         }    #T_59b22a9e_9968_11ea_9a09_f8da0c854c28row2_col4 {
#             width:  10em;
# ...
